# %% [markdown]
# <b>
# Kelompok : 8
# <br>
# Nama Kelompok : Automata
# <br>
# Dataset : Churn Prediction
# <br>
# Anggota Kelompok :
# <br>
# -	Achmad Jaelani Azizs Irphan
# <br>
# -	Aditya Yudha Isa
# <br>
# -	Atina Za'ima
# <br>
# -	Muhammad Akbar Pratama Putra
# <br>
# -	Tiara Kusumadewi
# <br>
# -	Wahidin
# </b>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_excel('./Dataset/E Commerce Dataset.xlsx', sheet_name='E Comm')
data.head()
# Out:
#    CustomerID  Churn  Tenure PreferredLoginDevice  CityTier  WarehouseToHome  \
# 0       50001      1     4.0         Mobile Phone         3              6.0
# 1       50002      1     NaN                Phone         1              8.0
# 2       50003      1     NaN                Phone         1             30.0
# 3       50004      1     0.0                Phone         3             15.0
# 4       50005      1     0.0                Phone         1             12.0
#
#   PreferredPaymentMode  Gender  HourSpendOnApp  NumberOfDeviceRegistered  \
# 0           Debit Card  Female             3.0                         3
# 1                  UPI    Male             3.0                         4
# 2           Debit Card    Male             2.0                         4
# 3           Debit Card    Male             2.0                         4
# 4                   CC    Male             NaN                         3
#
# ...

# %% [markdown]
# # Descriptive Statistics

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5630 entries, 0 to 5629
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   CustomerID                   5630 non-null   int64
#  1   Churn                        5630 non-null   int64
#  2   Tenure                       5366 non-null   float64
#  3   PreferredLoginDevice         5630 non-null   object
#  4   CityTier                     5630 non-null   int64
#  5   WarehouseToHome              5379 non-null   float64
#  6   PreferredPaymentMode         5630 non-null   object
#  7   Gender                       5630 non-null   object
#  8   HourSpendOnApp               5375 non-null   float64
#  9   NumberOfDeviceRegistered     5630 non-null   int64
#  10  PreferedOrderCat             5630 non-null   object
#  11  SatisfactionScore            5630 non-null   int64
#  12  MaritalStatus                5630 non-null   object
# ...

# %%
data.sample(10)
# Out:
#       CustomerID  Churn  Tenure PreferredLoginDevice  CityTier  \
# 1750       51751      1     0.0                Phone         1
# 4896       54897      0    22.0         Mobile Phone         1
# 1424       51425      0    19.0         Mobile Phone         2
# 847        50848      0     NaN             Computer         1
# 779        50780      0    21.0         Mobile Phone         1
# 3198       53199      0     9.0         Mobile Phone         1
# 5103       55104      0    20.0         Mobile Phone         2
# 4912       54913      1     1.0         Mobile Phone         1
# 4599       54600      1     1.0             Computer         1
# 3921       53922      0    20.0         Mobile Phone         1
#
#       WarehouseToHome PreferredPaymentMode  Gender  HourSpendOnApp  \
# 1750              9.0          Credit Card    Male             3.0
# 4896             11.0           Debit Card    Male             4.0
# 1424             11.0          Credit Card    Male             3.0
# ...

# %%
data.isna().sum()
# Out:
# CustomerID                       0
# Churn                            0
# Tenure                         264
# PreferredLoginDevice             0
# CityTier                         0
# WarehouseToHome                251
# PreferredPaymentMode             0
# Gender                           0
# HourSpendOnApp                 255
# NumberOfDeviceRegistered         0
# PreferedOrderCat                 0
# SatisfactionScore                0
# MaritalStatus                    0
# NumberOfAddress                  0
# Complain                         0
# OrderAmountHikeFromlastYear    265
# CouponUsed                     256
# OrderCount                     258
# DaySinceLastOrder              307
# CashbackAmount                   0
# dtype: int64

# %%
data_numerik = data[[
        'Churn', 'Tenure', 'CityTier', 'WarehouseToHome', 'HourSpendOnApp', 'NumberOfDeviceRegistered', 
        'SatisfactionScore', 'NumberOfAddress', 'Complain', 'OrderAmountHikeFromlastYear', 'CouponUsed',
        'OrderCount', 'DaySinceLastOrder', 'CashbackAmount'
    ]]
data_kategorik = data[['PreferredLoginDevice', 'PreferredPaymentMode', 'Gender', 'PreferedOrderCat', 'MaritalStatus']]

# %%
data_numerik.describe()
# Out:
#              Churn       Tenure     CityTier  WarehouseToHome  HourSpendOnApp  \
# count  5630.000000  5366.000000  5630.000000      5379.000000     5375.000000
# mean      0.168384    10.189899     1.654707        15.639896        2.931535
# std       0.374240     8.557241     0.915389         8.531475        0.721926
# min       0.000000     0.000000     1.000000         5.000000        0.000000
# 25%       0.000000     2.000000     1.000000         9.000000        2.000000
# 50%       0.000000     9.000000     1.000000        14.000000        3.000000
# 75%       0.000000    16.000000     3.000000        20.000000        3.000000
# max       1.000000    61.000000     3.000000       127.000000        5.000000
#
#        NumberOfDeviceRegistered  SatisfactionScore  NumberOfAddress  \
# count               5630.000000        5630.000000      5630.000000
# mean                   3.688988           3.066785         4.214032
# ...

# %%
data_kategorik.describe()
# Out:
#        PreferredLoginDevice PreferredPaymentMode Gender    PreferedOrderCat  \
# count                  5630                 5630   5630                5630
# unique                    3                    7      2                   6
# top            Mobile Phone           Debit Card   Male  Laptop & Accessory
# freq                   2765                 2314   3384                2050
#
#        MaritalStatus
# count           5630
# unique             3
# top          Married
# freq            2986

# %%
for col in data_kategorik:
    print('=================================')
    print('Value count kolom {} :'.format(col))
    print(data[col].value_counts())
    print('=================================\n')
# Out:
# ...
# Value count kolom PreferredLoginDevice :
# Mobile Phone    2765
# Computer        1634
# Phone           1231
# Name: PreferredLoginDevice, dtype: int64
# ...
#
# ...
# Value count kolom PreferredPaymentMode :
# Debit Card          2314
# Credit Card         1501
# E wallet             614
# UPI                  414
# COD                  365
# CC                   273
# Cash on Delivery     149
# Name: PreferredPaymentMode, dtype: int64
# ...
#
# ...
# Value count kolom Gender :
# Male      3384
# Female    2246
# Name: Gender, dtype: int64
# ...
#
# ...
# Value count kolom PreferedOrderCat :
# Laptop & Accessory    2050
# Mobile Phone          1271
# Fashion                826
# Mobile                 809
# Grocery                410
# Others                 264
# Name: PreferedOrderCat, dtype: int64
# ...
#
# ...
# Value count kolom MaritalStatus :
# Married     2986
# Single      1796
# Divorced     848
# Name: MaritalStatus, dtype: int64
# ...

# %%
data.isna().sum()
# Out:
# CustomerID                       0
# Churn                            0
# Tenure                         264
# PreferredLoginDevice             0
# CityTier                         0
# WarehouseToHome                251
# PreferredPaymentMode             0
# Gender                           0
# HourSpendOnApp                 255
# NumberOfDeviceRegistered         0
# PreferedOrderCat                 0
# SatisfactionScore                0
# MaritalStatus                    0
# NumberOfAddress                  0
# Complain                         0
# OrderAmountHikeFromlastYear    265
# CouponUsed                     256
# OrderCount                     258
# DaySinceLastOrder              307
# CashbackAmount                   0
# dtype: int64

# %%
data['Churn'].value_counts()
# Out:
# 0    4682
# 1     948
# Name: Churn, dtype: int64

# %% [markdown]
# # Univariate Analysis

# %%
plt.figure(figsize=(20, 5))
for i in range(0, len(data_numerik.columns)) :
    plt.subplot(2, 7, i + 1)
    sns.kdeplot(x=data[data_numerik.columns[i]], color='green')
    plt.title(data_numerik.columns[i])

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(20, 5))
for i in range(0, len(data_numerik.columns)) :
    plt.subplot(2, 7, i + 1)
    sns.boxplot(y=data[data_numerik.columns[i]], color='green')
    plt.title(data_numerik.columns[i])

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(20, 7))
for i in range(0, len(data_kategorik.columns)) :
    plt.subplot(2, 3, i + 1)
    sns.histplot(x=data[data_kategorik.columns[i]], data=data, kde=True)
    plt.title(data_kategorik.columns[i])

plt.tight_layout()
plt.show()

# %% [markdown]
# # Multivariate Analysis

# %%
plt.figure(figsize=(30, 10))
sns.heatmap(data.corr(), annot=True, cmap='Blues')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(20, 5))
for i in range(0, len(data_numerik.columns)) :
    plt.subplot(2, 7, i + 1)
    sns.kdeplot(x=data[data_numerik.columns[i]], color='green')
    plt.title(data_numerik.columns[i])

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(20, 10))
for i in range(0, len(data_numerik.columns) - 1) :
    plt.subplot(3, 5, i + 1)
    sns.kdeplot(data_numerik.loc[(data_numerik['Churn']==0), data_numerik.columns[i + 1]], color='r', shade=True, Label='Not Churn')
    sns.kdeplot(data_numerik.loc[(data_numerik['Churn']==1), data_numerik.columns[i + 1]], color='b', shade=True, Label='Churn')
    plt.title(data_numerik.columns[i + 1])
    plt.legend()

plt.tight_layout()
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:949: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   scout = self.ax.fill_between([], [], **plot_kws)
# C:\Users\USER\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:992: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   artist = ax.fill_between(
# C:\Users\USER\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:949: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   scout = self.ax.fill_between([], [], **plot_kws)
# ...

# %% [markdown]
# <b>1. Apa saja attributes dan target output dari dataset yang dipilih?</b>
# <br>
# Fitur yang dapat digunakan di dalam dataset ini adalah seluruh fitur kecuali fitur CustomerID, WareHouseToHome, OrderAmountHikeFromlastYear, dan CouponUsed. Lalu dapat diketahui bahwa target dari dataset ini adalah fitur Churn yang dapat diprediksi hasil akhirnya berdasarkan sejumlah fitur yang ada.
#
# <b>2. Untuk setiap feature yang disiapkan, apakah sudah dicek distribusinya terhadap variabel target?</b>
# <br>
# Untuk distribusi setiap fitur terhadap variabel sudah ter-visualiasi, namun dapat dilihat bahwa setiap fitur tidak memiliki hubungan linear dengan Churn, ini dikarenakan dataset ini tidak bersifat regresi dan bersifat prediksi kategori klasifikasi. Terdapat beberapa fitur yang memiliki hubungan non linear dengan fitur target yang ada. Oleh karena itu untuk membuat model dari dataset ini diperlukan algoritma supervised learning yang non linear dan non regresi.

# %% [markdown]
# <b>3. Apakah sudah menemukan beberapa insight menarik dari dataset tersebut, termasuk visualisasi yang mendukung serta kaitan dari problem utama yang ingin diselesaikan?</b>
# <br>

# %%
data.head()
# Out:
#    CustomerID  Churn  Tenure PreferredLoginDevice  CityTier  WarehouseToHome  \
# 0       50001      1     4.0         Mobile Phone         3              6.0
# 1       50002      1     NaN                Phone         1              8.0
# 2       50003      1     NaN                Phone         1             30.0
# 3       50004      1     0.0                Phone         3             15.0
# 4       50005      1     0.0                Phone         1             12.0
#
#   PreferredPaymentMode  Gender  HourSpendOnApp  NumberOfDeviceRegistered  \
# 0           Debit Card  Female             3.0                         3
# 1                  UPI    Male             3.0                         4
# 2           Debit Card    Male             2.0                         4
# 3           Debit Card    Male             2.0                         4
# 4                   CC    Male             NaN                         3
#
# ...

# %% [markdown]
# ### Data Complain dan Churn

# %%
dataComplain = data.groupby(['Complain', 'Churn']).agg({'CustomerID' : 'nunique'}).reset_index().rename(columns={'CustomerID' : 'Jumlah Customer'})
dataComplain['Complain'] = dataComplain['Complain'].replace([0, 1], ['Not Complain', 'Complain'])
dataComplain['Presentase'] = (dataComplain['Jumlah Customer'] / dataComplain.groupby('Complain')['Jumlah Customer'].transform('sum')) * 100
dataComplain
# Out:
#        Complain  Churn  Jumlah Customer  Presentase
# 0  Not Complain      0             3586   89.071038
# 1  Not Complain      1              440   10.928962
# 2      Complain      0             1096   68.329177
# 3      Complain      1              508   31.670823

# %%
plt.figure(figsize=(10, 7))
barplot = sns.barplot(x='Complain', y='Jumlah Customer', data=dataComplain, hue='Churn')

for i in barplot.patches:
    barplot.annotate(
        format(round(i.get_height())), 
        (i.get_x() + i.get_width() / 2, i.get_height()), 
        ha='center', 
        va='center', 
        size=11,
        xytext=(0, 9),
        textcoords='offset points'
    )

plt.tight_layout()
plt.show()

# %% [markdown]
# <b>Insight</b>
# <br>
# Diketahui bahwa customer lebih banyak yang tidak complain terkait produk yang dibeli, namun dari data customer yang tidak complain tersebut tetap ada customer yang Churn dengan persentase 10.9% dari total data Not Complain. Sementara itu dari data customer yang Complain diketahui hampir setengahnya dari data bahwa customer yang Complain berpotensi untuk berhenti berlangganan dengan persentase 31.6%.
#
# <b>Rekomendasi</b>
# <br>
# Meningkatkan kualitas dari customer service yang berhubungan langsung dengan masalah customer sehingga dapat menekan angka Churn Rate dari customer yang mengajukan Complain serta memberikan sejumlah form feedback terkait customer yang tidak complain namun Churn untuk mengetahui kekurangan yang ada di dalam perusahaan.

# %% [markdown]
# ### Hubungan Churn dengan Metode Pembayaran

# %%
dataPembayaran = data.copy()
dataPembayaran['PreferredPaymentMode'].replace(['CC', 'COD', 'UPI'], ['Credit Card', 'Cash on Delivery', 'E wallet'], inplace=True)
dataPembayaran['PreferedOrderCat'].replace('Mobile', 'Mobile Phone', inplace=True)
dataPembayaran = dataPembayaran.groupby(['PreferredPaymentMode', 'Churn']).agg({'CustomerID' : 'nunique'}).reset_index().rename(columns={'CustomerID' : 'Jumlah Customer'})
dataPembayaran['Presentase'] = (dataPembayaran['Jumlah Customer'] / dataPembayaran.groupby('PreferredPaymentMode')['Jumlah Customer'].transform('sum')) * 100
dataPembayaran
# Out:
#   PreferredPaymentMode  Churn  Jumlah Customer  Presentase
# 0     Cash on Delivery      0              386   75.097276
# 1     Cash on Delivery      1              128   24.902724
# 2          Credit Card      0             1522   85.794814
# 3          Credit Card      1              252   14.205186
# 4           Debit Card      0             1958   84.615385
# 5           Debit Card      1              356   15.384615
# 6             E wallet      0              816   79.377432
# 7             E wallet      1              212   20.622568

# %%
plt.figure(figsize=(10, 7))
barplot = sns.barplot(x='PreferredPaymentMode', y='Jumlah Customer', data=dataPembayaran, hue='Churn')

for i in barplot.patches:
    barplot.annotate(
        format(round(i.get_height())), 
        (i.get_x() + i.get_width() / 2, i.get_height()), 
        ha='center', 
        va='center', 
        size=11,
        xytext=(0, 9),
        textcoords='offset points'
    )

plt.tight_layout()
plt.show()

# %% [markdown]
# <b>Insight</b>
# <br>
# Terlihat bahwa metode pembayaran dengan jumlah terbanyak adalah pembayaran dengan Debit Card. Dilihat juga bahwa Churn yang terdapat di Debit Card lebih besar dibandingkan dengan metode pembayaran lainnya. Dilihat dari persentase yang telah dilakukan, bahwa metode pembayaran menggunakan Credit Card lebih kecil peluang terjadinya customer yang Churn dibandingkan dengan metode pembayaran lain dengan persentase Churn sebesar 14.2% dari total data Credit Card.
#
# <b>Rekomendasi</b>
# <br>
# Menekan terjadinya angka Churn Rate dikeseluruhan metode pembayaran dengan cara memberikan promo seperti gratis ongkir untuk kesetiap jenis transaksi dengan metode pembayaran apapun beserta customer mendapatkan sejumlah diskon. Hal ini diharapkan selain menekan Churn Rate, juga dapat menambah jumlah customer di tiap metode pembayaran yang dapat menguntungkan perusahaan dan mitra perusahaan.

# %% [markdown]
# ### Pengaruh Marital Status Terhadap Churn

# %%
dataStatus = data[data['Churn'] == 1]
dataStatus = dataStatus.groupby(['Churn', 'MaritalStatus', 'Gender']).agg({'CustomerID' : 'nunique'}).reset_index().rename(columns={'CustomerID' : 'Jumlah Customer'})
dataStatus
# Out:
#    Churn MaritalStatus  Gender  Jumlah Customer
# 0      1      Divorced  Female               48
# 1      1      Divorced    Male               76
# 2      1       Married  Female              112
# 3      1       Married    Male              232
# 4      1        Single  Female              188
# 5      1        Single    Male              292

# %%
plt.figure(figsize=(10, 7))
barplot = sns.barplot(x='MaritalStatus', y='Jumlah Customer', data=dataStatus, hue='Gender')

for i in barplot.patches:
    barplot.annotate(
        format(round(i.get_height())), 
        (i.get_x() + i.get_width() / 2, i.get_height()), 
        ha='center', 
        va='center', 
        size=11,
        xytext=(0, 9),
        textcoords='offset points'
    )

plt.tight_layout()
plt.show()

# %% [markdown]
# <b>Insight</b>
# <br>
# Dapat diketahui dari data yang berhenti berlangganan bahwa di dominasi oleh laki - laki dan perempuan yang single dibandingkan dengan yang statusnya menikah. Dapat diketahui juga bahwa dikedua status baik single maupun menikah, laki - laki diketahui lebih cenderung untuk churn dibandingkan dengan perempuan.
#
# <b>Rekomendasi</b>
# <br>
# Dapat memberikan sejumlah event diwaktu tertentu seperti event olahraga dengan memberikan diskon untuk peralatan olahraga, atau event untuk alat elektronik dan memberikan diskon untuk peralatan elektronik yang dapat menarik minat laki - laki untuk membeli suatu produk ataupun event Fashion untuk menarik minat perempuan. Lalu juga dapat diberikan sejumlah diskon khusus kesejumlah customer tertentu untuk peralatan alat rumah tangga atau alat kebutuhan anak - anak untuk menekan angka Churn serta menambah customer di status Married atau Divorced.

# %% [markdown]
# ### Last Order ke Churn

# %%
dataOrder = data.copy()

dataOrder['Tingkatan Last Order'] = dataOrder['DaySinceLastOrder'].apply(
        lambda x: '1 - 7 Hari' if (x <= 7) else '8 - 14 Hari' if (7 < x <= 14) else '15 - 21 Hari' if (15 < x <= 21) else '22 - 28 Hari' if (21 < x <= 28) else '> 4 Minggu'
    )

dataOrder.head()
# Out:
#    CustomerID  Churn  Tenure PreferredLoginDevice  CityTier  WarehouseToHome  \
# 0       50001      1     4.0         Mobile Phone         3              6.0
# 1       50002      1     NaN                Phone         1              8.0
# 2       50003      1     NaN                Phone         1             30.0
# 3       50004      1     0.0                Phone         3             15.0
# 4       50005      1     0.0                Phone         1             12.0
#
#   PreferredPaymentMode  Gender  HourSpendOnApp  NumberOfDeviceRegistered  ...  \
# 0           Debit Card  Female             3.0                         3  ...
# 1                  UPI    Male             3.0                         4  ...
# 2           Debit Card    Male             2.0                         4  ...
# 3           Debit Card    Male             2.0                         4  ...
# 4                   CC    Male             NaN                         3  ...
#
# ...

# %%
dataOrderGroup = dataOrder.groupby(['Tingkatan Last Order', 'Churn']).agg({'CustomerID' : 'nunique'}).reset_index().rename(columns={'CustomerID' : 'Jumlah Customer'})
dataOrderGroupCopy = dataOrderGroup.copy()
dataOrderGroup.iloc[4] = dataOrderGroupCopy.iloc[2]
dataOrderGroup.iloc[2] = dataOrderGroupCopy.iloc[3]
dataOrderGroup.iloc[3] = dataOrderGroupCopy.iloc[4]
dataOrderGroup
# Out:
#   Tingkatan Last Order  Churn  Jumlah Customer
# 0           1 - 7 Hari      0             3250
# 1           1 - 7 Hari      1              771
# 2          8 - 14 Hari      0             1122
# 3          8 - 14 Hari      1              118
# 4         15 - 21 Hari      0               40
# 5           > 4 Minggu      0              270
# 6           > 4 Minggu      1               59

# %%
plt.figure(figsize=(15, 5))
sns.lineplot(x='Tingkatan Last Order', y='Jumlah Customer', data=dataOrderGroup, hue='Churn')
plt.tight_layout()
plt.show()

# %% [markdown]
# <b>Insight</b>
# <br>
# Diketahui bahwa pada minggu pertama ia terakhir membeli produk lah letak berpotensi Churn lebih besar dibandingkan di minggu - minggu setelahnya. Hal ini bisa saja disebabkan dengan adanya suatu promo atau diskon khusus tertentu yang customer beli lalu tidak melakukan pembelian kembali setelah promo atau diskon tersebut usai.
#
# <b>Rekomendasi</b>
# <br>
# Customer dapat diberikan seperti promo atau voucher tambahan yang bisa didapatkan secara gratis setiap ia melakukan pembelian suatu produk sehingga dapat menekan Churn Rate di minggu pertama terakhir customer membeli produk

# %% [markdown]
# ### Hubungan Tenure dengan Churn

# %%
dataTenure = data.copy()
dataTenure.head()
# Out:
#    CustomerID  Churn  Tenure PreferredLoginDevice  CityTier  WarehouseToHome  \
# 0       50001      1     4.0         Mobile Phone         3              6.0
# 1       50002      1     NaN                Phone         1              8.0
# 2       50003      1     NaN                Phone         1             30.0
# 3       50004      1     0.0                Phone         3             15.0
# 4       50005      1     0.0                Phone         1             12.0
#
#   PreferredPaymentMode  Gender  HourSpendOnApp  NumberOfDeviceRegistered  \
# 0           Debit Card  Female             3.0                         3
# 1                  UPI    Male             3.0                         4
# 2           Debit Card    Male             2.0                         4
# 3           Debit Card    Male             2.0                         4
# 4                   CC    Male             NaN                         3
#
# ...

# %%
dataTenure['Tenure'].unique()
# Out:
# array([ 4., nan,  0., 13., 11.,  9., 19., 20., 14.,  8., 18.,  5.,  2.,
#        30.,  1., 23.,  3., 29.,  6., 26., 28.,  7., 24., 25., 10., 15.,
#        22., 27., 16., 12., 21., 17., 50., 60., 31., 51., 61.])

# %%
dataTenure['Tenure'].fillna(dataTenure['Tenure'].median(), inplace=True)
dataTenure['Tenure'] = dataTenure['Tenure'].astype(int)
dataTenure.head()
# Out:
#    CustomerID  Churn  Tenure PreferredLoginDevice  CityTier  WarehouseToHome  \
# 0       50001      1       4         Mobile Phone         3              6.0
# 1       50002      1       9                Phone         1              8.0
# 2       50003      1       9                Phone         1             30.0
# 3       50004      1       0                Phone         3             15.0
# 4       50005      1       0                Phone         1             12.0
#
#   PreferredPaymentMode  Gender  HourSpendOnApp  NumberOfDeviceRegistered  \
# 0           Debit Card  Female             3.0                         3
# 1                  UPI    Male             3.0                         4
# 2           Debit Card    Male             2.0                         4
# 3           Debit Card    Male             2.0                         4
# 4                   CC    Male             NaN                         3
#
# ...

# %%
dataTenureCust = dataTenure.groupby(['Churn', 'Tenure']).agg({'CustomerID' : 'count'}).reset_index().rename(columns={'CustomerID' : 'Jumlah Customer'})
dataTenureCust
# Out:
#     Churn  Tenure  Jumlah Customer
# 0       0       0              236
# 1       0       1              341
# 2       0       2              153
# 3       0       3              177
# 4       0       4              183
# 5       0       5              188
# 6       0       6              175
# 7       0       7              205
# 8       0       8              247
# 9       0       9              418
# 10      0      10              199
# 11      0      11              184
# 12      0      12              175
# 13      0      13              168
# 14      0      14              162
# 15      0      15              149
# 16      0      16              139
# 17      0      17              102
# 18      0      18              117
# 19      0      19              128
# 20      0      20               93
# 21      0      21               74
# 22      0      22               76
# 23      0      23               89
# 24      0      24               75
# 25      0      25               59
# ...

# %%
plt.figure(figsize=(25, 7))
sns.barplot(x='Tenure', y='Jumlah Customer', data=dataTenureCust, hue='Churn')

plt.tight_layout()
plt.show()

# %% [markdown]
# <b>Insight</b>
# <br>
# Customer sangat riskan berpotensi untuk churn pada saat customer baru saja bergabung BukaGerai pada 0 sampai 1 bulan pertama.
#
# <b>Rekomendasi</b>
# <br>
# Memberikan voucher atau penawaran menarik untuk customer dengan awal masa jabatan, sehingga diharapkan dapat menekan angka churn yang ada.

# %% [markdown]
# ## Churn terhadap kategori pembelian dan gender

# %%
dataOrderCat = data[data['Churn'] == 1]
dataOrderCat['PreferedOrderCat'].replace('Mobile', 'Mobile Phone', inplace=True)
dataOrder = dataOrderCat.groupby(['PreferedOrderCat', 'Gender']).agg({'CustomerID' : 'nunique'}).reset_index()
dataOrder
# Out:
# C:\Users\USER\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\generic.py:6610: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)
#      PreferedOrderCat  Gender  CustomerID
# 0             Fashion  Female          48
# 1             Fashion    Male          80
# 2             Grocery  Female           4
# 3             Grocery    Male          16
# 4  Laptop & Accessory  Female          72
# 5  Laptop & Accessory    Male         138
# 6        Mobile Phone  Female         212
# 7        Mobile Phone    Male         358
# 8              Others  Female          12
# 9              Others    Male           8

# %%
dataCash = data.copy()
dataCash.head()
# Out:
#    CustomerID  Churn  Tenure PreferredLoginDevice  CityTier  WarehouseToHome  \
# 0       50001      1     4.0         Mobile Phone         3              6.0
# 1       50002      1     NaN                Phone         1              8.0
# 2       50003      1     NaN                Phone         1             30.0
# 3       50004      1     0.0                Phone         3             15.0
# 4       50005      1     0.0                Phone         1             12.0
#
#   PreferredPaymentMode  Gender  HourSpendOnApp  NumberOfDeviceRegistered  \
# 0           Debit Card  Female             3.0                         3
# 1                  UPI    Male             3.0                         4
# 2           Debit Card    Male             2.0                         4
# 3           Debit Card    Male             2.0                         4
# 4                   CC    Male             NaN                         3
#
# ...

# %%
plt.figure(figsize=(15, 7))
barplot = sns.barplot(x='PreferedOrderCat', y='CustomerID', data=dataOrder, hue='Gender')

for i in barplot.patches:
    barplot.annotate(
        format(round(i.get_height())), 
        (i.get_x() + i.get_width() / 2, i.get_height()), 
        ha='center', 
        va='center', 
        size=11,
        xytext=(0, 9),
        textcoords='offset points'
    )

plt.tight_layout()
plt.show()

# %% [markdown]
# <b>Insight</b>
# <br>
# Gender Male lebih berpotensi untuk Churn saat membeli suatu produk elektronik (laptop & accessory & Mobile Phone) jika dibandingkan dengan kategori produk lainnya.
#
# <b>Rekomendasi</b>
# <br>
# Meningkatkan kualitas mitra toko elektronik yang berada di BukaGerai, sehingga customer lebih merasa aman terhadap produk dan kualitas dari produk tersebut.

# %% [markdown]
# ### Perhitungan cost & revenue voucher cashback tenure

# %%
dataLain = dataCash[((dataCash['Tenure'] == 0.0) | (dataCash['Tenure'] == 1.0))]
dataLain.head()
# Out:
#     CustomerID  Churn  Tenure PreferredLoginDevice  CityTier  WarehouseToHome  \
# 3        50004      1     0.0                Phone         3             15.0
# 4        50005      1     0.0                Phone         1             12.0
# 5        50006      1     0.0             Computer         1             22.0
# 12       50013      1     0.0                Phone         1             11.0
# 13       50014      1     0.0                Phone         1             15.0
#
#    PreferredPaymentMode  Gender  HourSpendOnApp  NumberOfDeviceRegistered  \
# 3            Debit Card    Male             2.0                         4
# 4                    CC    Male             NaN                         3
# 5            Debit Card  Female             3.0                         5
# 12                  COD    Male             2.0                         3
# 13                   CC    Male             3.0                         4
#
# ...

# %%
dataLain['CashbackAmount'].sum()
# Out:
# 183678.12999999998
